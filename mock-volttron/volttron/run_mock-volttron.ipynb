# %%
import threading
import traceback
from agents.InterfaceAgent.api import agent as interface_agent
from agents.RecvAgent.recv import agent as recv_agent

# Provide correct paths to your config files
interface_config_path = "config/interface_config_mock"
recv_config_path = "config/recv_config_mock"

def run_interface_agent():
    try:
        interface_agent.main([None, interface_config_path])
    except Exception:
        traceback.print_exc()

def run_recv_agent():
    try:
        recv_agent.main([None, recv_config_path])
    except Exception:
        traceback.print_exc()

t1 = threading.Thread(target=run_interface_agent)
t2 = threading.Thread(target=run_recv_agent)

t1.start()
t2.start()
# Out:
# [MOCK] Starting agent: InterfaceAgent (version=3.3)
# [MOCK] Starting agent: RecvAgent (version=3.3)
# INFO:agents.RecvAgent.recv.agent:Test Message
# INFO:agents.RecvAgent.recv.agent:subscribed to devices/ORNL/FRP2/all
# [MOCK] Subscribing to devices/ORNL/FRP2/all
# INFO:agents.RecvAgent.recv.agent:Received: devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/control
# INFO:agents.RecvAgent.recv.agent:Received: devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/control
# INFO:agents.RecvAgent.recv.agent:Received: devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/control
# INFO:agents.RecvAgent.recv.agent:Received: devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/control
# INFO:agents.RecvAgent.recv.agent:Received: devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/all
# [MOCK] Publishing to devices/ORNL/FRP2/control
# [MOCK] Error in scheduled function: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /get_point (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001AF1E9DAAD0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
